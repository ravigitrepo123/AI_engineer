# %% [markdown]
# # LIST

# %%
l = [] 
l
# Out:
# []

# %%
print(len(l))
# Out:
# 0

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
id(l)
# Out:
# 2897926577664

# %%
l.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
l
# Out:
# []

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.append(30, 40, 50 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l.append(30, 40, 50 )
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l.append([20, 40, 50])
l
# Out:
# [10, 20, 30, 40, 50, 10, [20, 40, 50]]

# %%
l.append(100)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, [20, 40, 50], 100]

# %%
l1 = [1, 2.3, True, 1+2j, 'prakash']
l1
# Out:
# [1, 2.3, True, (1+2j), 'prakash']

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, [20, 40, 50], 100]
# [1, 2.3, True, (1+2j), 'prakash']

# %%
print(len(l))
print(len(l1))
# Out:
# 8
# 5

# %%
l1
# Out:
# [1, 2.3, True, (1+2j), 'prakash']

# %%
icici = [12345, 23031985, 'nit', 'Business', 'cizps4566']
icici
# Out:
# [12345, 23031985, 'nit', 'Business', 'cizps4566']

# %%
icici[:]
# Out:
# [12345, 23031985, 'nit', 'Business', 'cizps4566']

# %%
icici[0]
# Out:
# 12345

# %%
icici[0] = 6789

# %%
icici
# Out:
# [6789, 23031985, 'nit', 'Business', 'cizps4566']

# %%
print(l)
print(l1)
print(icici)
# Out:
# [10, 20, 30, 40, 50, 10, [20, 40, 50], 100]
# [1, 2.3, True, (1+2j), 'prakash']
# [6789, 23031985, 'nit', 'Business', 'cizps4566']

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, [20, 40, 50], 100]

# %%
l[4] = 45
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l1
# Out:
# [1, 2.3, True, (1+2j), 'prakash']

# %%
print(l)
print(l1)
print(icici)
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]
# [1, 2.3, True, (1+2j), 'prakash']
# [6789, 23031985, 'nit', 'Business', 'cizps4566']

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [1, 2.3, True, (1+2j), 'prakash']

# %%
l1
# Out:
# [1, 2.3, True, (1+2j), 'prakash']

# %%
l1 == l2
# Out:
# True

# %%
id(l1) == id(l2)
# Out:
# False

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[:]
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[-1]
# Out:
# 100

# %%
l[::-1]
# Out:
# [100, [20, 40, 50], 10, 45, 40, 30, 20, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[:5]
# Out:
# [10, 20, 30, 40, 45]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l[20]
#
# IndexError: list index out of range

# %%
l[:20] # print from start till 19
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[:200]
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[0:20:5]
# Out:
# [10, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[::3]
# Out:
# [10, 40, [20, 40, 50]]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[::-3]
# Out:
# [100, 45, 20]

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
print(l)
print(l1)
print(l2)
print(icici)
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]
# [1, 2.3, True, (1+2j), 'prakash']
# [1, 2.3, True, (1+2j), 'prakash']
# [6789, 23031985, 'nit', 'Business', 'cizps4566']

# %%
icici.clear()

# %%
icici
# Out:
# []

# %%
del icici

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l.count(40)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 45, 10, [20, 40, 50], 100]

# %%
l[6]
# Out:
# [20, 40, 50]

# %%
print(l[6][0])
print(l[6][1])
print(l[6][2])
# Out:
# 20
# 40
# 50

# %%
l.count(2.3)
# Out:
# 0

# %%
l.count()
